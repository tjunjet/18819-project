# %%
# !/home/ec2-user/anaconda3/envs/Braket/bin/python -m pip install torch seaborn scikit-learn pennylane amazon-braket-pennylane-plugin
# Out:
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (2.5.1)
# Requirement already satisfied: seaborn in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: pennylane in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (0.35.1)
# Requirement already satisfied: amazon-braket-pennylane-plugin in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (1.28.0)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: rustworkx in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from pennylane) (0.15.1)
# Requirement already satisfied: autograd in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from pennylane) (1.7.0)
# Requirement already satisfied: toml in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from pennylane) (1.4.4)
# Requirement already satisfied: semantic-version>=2.7 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from pennylane) (2.10.0)
# Requirement already satisfied: autoray>=0.6.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from pennylane) (0.6.12)
# Requirement already satisfied: cachetools in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from pennylane) (5.5.0)
# Requirement already satisfied: pennylane-lightning>=0.35 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from pennylane) (0.35.1)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from pennylane) (2.32.3)
# Requirement already satisfied: amazon-braket-sdk>=1.47.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from amazon-braket-pennylane-plugin) (1.87.0)
# Requirement already satisfied: amazon-braket-schemas>=1.21.3 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (1.22.0)
# Requirement already satisfied: amazon-braket-default-simulator>=1.26.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (1.26.0)
# Requirement already satisfied: oqpy~=0.3.5 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (0.3.6)
# Requirement already satisfied: backoff in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (2.2.1)
# Requirement already satisfied: boltons in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (24.0.0)
# Requirement already satisfied: boto3>=1.28.53 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (1.35.0)
# Requirement already satisfied: cloudpickle==2.2.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (2.2.1)
# Requirement already satisfied: nest-asyncio in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (1.6.0)
# Requirement already satisfied: openpulse in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (1.0.0)
# Requirement already satisfied: openqasm3 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (1.0.0)
# Requirement already satisfied: backports.entry-points-selectable in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from requests->pennylane) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from requests->pennylane) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from requests->pennylane) (2024.8.30)
# Requirement already satisfied: opt-einsum in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (3.4.0)
# Requirement already satisfied: pydantic>2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (2.9.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (4.9.2)
# Requirement already satisfied: botocore<1.36.0,>=1.35.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from boto3>=1.28.53->amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (1.35.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from boto3>=1.28.53->amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from boto3>=1.28.53->amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (0.10.2)
# Requirement already satisfied: mypy-extensions>=0.2.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from oqpy~=0.3.5->amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (1.0.0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from pydantic>2->amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.10/site-packages (from pydantic>2->amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk>=1.47.0->amazon-braket-pennylane-plugin) (2.23.4)

# %% [markdown]
# ## Import Packages

# %%
# Import packages
# %matplotlib inline
import pandas as pd
import pennylane as qml
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Sklearn Packages
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# Sklearn Evaluation Metrics
from sklearn import metrics
from sklearn.metrics import mean_squared_error, precision_score, confusion_matrix, accuracy_score

# Visualizes all the columns
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)


from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

from pennylane.templates import AngleEmbedding, StronglyEntanglingLayers
from pennylane.operation import Tensor

import matplotlib.pyplot as plt

np.random.seed(42)

# %% [markdown]
# ## Examining Data

# %%
df = pd.read_csv('exoplanets_2018.csv')

df = df.rename(columns={'kepid':'KepID',
'kepoi_name':'KOIName',
'kepler_name':'KeplerName',
'koi_disposition':'ExoplanetArchiveDisposition',
'koi_pdisposition':'DispositionUsingKeplerData',
'koi_score':'DispositionScore',
'koi_fpflag_nt':'NotTransit-LikeFalsePositiveFlag',
'koi_fpflag_ss':'koi_fpflag_ss',
'koi_fpflag_co':'CentroidOffsetFalsePositiveFlag',
'koi_fpflag_ec':'EphemerisMatchIndicatesContaminationFalsePositiveFlag',
'koi_period':'OrbitalPeriod[days',
'koi_period_err1':'OrbitalPeriodUpperUnc.[days',
'koi_period_err2':'OrbitalPeriodLowerUnc.[days',
'koi_time0bk':'TransitEpoch[BKJD',
'koi_time0bk_err1':'TransitEpochUpperUnc.[BKJD',
'koi_time0bk_err2':'TransitEpochLowerUnc.[BKJD',
'koi_impact':'ImpactParamete',
'koi_impact_err1':'ImpactParameterUpperUnc',
'koi_impact_err2':'ImpactParameterLowerUnc',
'koi_duration':'TransitDuration[hrs',
'koi_duration_err1':'TransitDurationUpperUnc.[hrs',
'koi_duration_err2':'TransitDurationLowerUnc.[hrs',
'koi_depth':'TransitDepth[ppm',
'koi_depth_err1':'TransitDepthUpperUnc.[ppm',
'koi_depth_err2':'TransitDepthLowerUnc.[ppm',
'koi_prad':'PlanetaryRadius[Earthradii',
'koi_prad_err1':'PlanetaryRadiusUpperUnc.[Earthradii',
'koi_prad_err2':'PlanetaryRadiusLowerUnc.[Earthradii',
'koi_teq':'EquilibriumTemperature[K',
'koi_teq_err1':'EquilibriumTemperatureUpperUnc.[K',
'koi_teq_err2':'EquilibriumTemperatureLowerUnc.[K',
'koi_insol':'InsolationFlux[Earthflux',
'koi_insol_err1':'InsolationFluxUpperUnc.[Earthflux',
'koi_insol_err2':'InsolationFluxLowerUnc.[Earthflux',
'koi_model_snr':'TransitSignal-to-Nois',
'koi_tce_plnt_num':'TCEPlanetNumbe',
'koi_tce_delivname':'TCEDeliver',
'koi_steff':'StellarEffectiveTemperature[K',
'koi_steff_err1':'StellarEffectiveTemperatureUpperUnc.[K',
'koi_steff_err2':'StellarEffectiveTemperatureLowerUnc.[K',
'koi_slogg':'StellarSurfaceGravity[log10(cm/s**2)',
'koi_slogg_err1':'StellarSurfaceGravityUpperUnc.[log10(cm/s**2)',
'koi_slogg_err2':'StellarSurfaceGravityLowerUnc.[log10(cm/s**2)',
'koi_srad':'StellarRadius[Solarradii',
'koi_srad_err1':'StellarRadiusUpperUnc.[Solarradii',
'koi_srad_err2':'StellarRadiusLowerUnc.[Solarradii',
'ra':'RA[decimaldegrees',
'dec':'Dec[decimaldegrees',
'koi_kepmag':'Kepler-band[mag]'
})


df['ExoplanetCandidate'] = df['DispositionUsingKeplerData'].apply(lambda x: 1 if x == 'CANDIDATE' else 0)
df['ExoplanetConfirmed'] = df['ExoplanetArchiveDisposition'].apply(lambda x: 2 if x == 'CONFIRMED' else 1 if x == 'CANDIDATE' else 0 )
df.drop(columns=['KeplerName','KOIName','EquilibriumTemperatureUpperUnc.[K',
                 'KepID','ExoplanetArchiveDisposition','DispositionUsingKeplerData',
                 'NotTransit-LikeFalsePositiveFlag','koi_fpflag_ss','CentroidOffsetFalsePositiveFlag',
                 'EphemerisMatchIndicatesContaminationFalsePositiveFlag','TCEDeliver',
                 'EquilibriumTemperatureLowerUnc.[K'], inplace=True)
df.dropna(inplace=True)
df.shape
# Out:
# (7803, 39)

# %% [markdown]
# ### Important Functions

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(axis=1)
    return df[indices_to_keep].astype(np.float64)

clean_dataset(df)
# Out:
#       DispositionScore  OrbitalPeriod[days  OrbitalPeriodUpperUnc.[days  \
# 0                1.000            9.488036                 2.780000e-05
# 1                0.969           54.418383                 2.480000e-04
# 2                0.000           19.899140                 1.490000e-05
# 3                0.000            1.736952                 2.630000e-07
# 4                1.000            2.525592                 3.760000e-06
# ...                ...                 ...                          ...
# 9559             0.000            0.527699                 1.160000e-07
# 9560             0.497            1.739849                 1.780000e-05
# 9561             0.021            0.681402                 2.430000e-06
# 9562             0.092          333.486169                 4.240000e-03
# 9563             0.000            4.856035                 6.360000e-05
#
#       OrbitalPeriodLowerUnc.[days  TransitEpoch[BKJD  \
# 0                   -2.780000e-05         170.538750
# 1                   -2.480000e-04         162.513840
# 2                   -1.490000e-05         175.850252
# 3                   -2.630000e-07         170.307565
# 4                   -3.760000e-06         171.595550
# ...                           ...                ...
# 9559                -1.160000e-07         131.705093
# 9560                -1.780000e-05         133.001270
# 9561                -2.430000e-06         132.181750
# 9562                -4.240000e-03         153.615010
# 9563                -6.360000e-05         135.993300
#
#       TransitEpochUpperUnc.[BKJD  TransitEpochLowerUnc.[BKJD  ImpactParamete  \
# 0                       0.002160                   -0.002160           0.146
# 1                       0.003520                   -0.003520           0.586
# 2                       0.000581                   -0.000581           0.969
# 3                       0.000115                   -0.000115           1.276
# 4                       0.001130                   -0.001130           0.701
# ...                          ...                         ...             ...
# 9559                    0.000170                   -0.000170           1.252
# 9560                    0.007690                   -0.007690           0.043
# 9561                    0.002850                   -0.002850           0.147
# 9562                    0.005070                   -0.005070           0.214
# 9563                    0.010800                   -0.010800           0.134
#
#       ImpactParameterUpperUnc  ImpactParameterLowerUnc  TransitDuration[hrs  \
# 0                       0.318                   -0.146              2.95750
# 1                       0.059                   -0.443              4.50700
# 2                       5.126                   -0.077              1.78220
# 3                       0.115                   -0.092              2.40641
# 4                       0.235                   -0.478              1.65450
# ...                       ...                      ...                  ...
# 9559                    0.051                   -0.049              3.22210
# 9560                    0.423                   -0.043              3.11400
# 9561                    0.309                   -0.147              0.86500
# 9562                    0.255                   -0.214              3.19900
# 9563                    0.323                   -0.134              3.07800
#
#       TransitDurationUpperUnc.[hrs  TransitDurationLowerUnc.[hrs  \
# 0                          0.08190                      -0.08190
# 1                          0.11600                      -0.11600
# 2                          0.03410                      -0.03410
# 3                          0.00537                      -0.00537
# 4                          0.04200                      -0.04200
# ...                            ...                           ...
# 9559                       0.01740                      -0.01740
# 9560                       0.22900                      -0.22900
# 9561                       0.16200                      -0.16200
# 9562                       0.22900                      -0.22900
# 9563                       0.28300                      -0.28300
#
#       TransitDepth[ppm  TransitDepthUpperUnc.[ppm  TransitDepthLowerUnc.[ppm  \
# 0                616.0                       19.5                      -19.5
# 1                875.0                       35.5                      -35.5
# 2              10800.0                      171.0                     -171.0
# 3               8080.0                       12.8                      -12.8
# 4                603.0                       16.9                      -16.9
# ...                ...                        ...                        ...
# 9559            1580.0                        4.6                       -4.6
# 9560              48.5                        5.4                       -5.4
# 9561             104.0                       14.7                      -14.7
# 9562             639.0                       52.7                      -52.7
# 9563              76.7                       10.8                      -10.8
#
#       PlanetaryRadius[Earthradii  PlanetaryRadiusUpperUnc.[Earthradii  \
# 0                           2.26                                 0.26
# 1                           2.83                                 0.32
# 2                          14.60                                 3.92
# 3                          33.46                                 8.50
# 4                           2.75                                 0.88
# ...                          ...                                  ...
# 9559                       29.35                                 7.70
# 9560                        0.72                                 0.24
# 9561                        1.07                                 0.36
# 9562                       19.30                                 0.55
# 9563                        1.05                                 0.36
#
#       PlanetaryRadiusLowerUnc.[Earthradii  EquilibriumTemperature[K  \
# 0                                   -0.15                     793.0
# 1                                   -0.19                     443.0
# 2                                   -1.31                     638.0
# 3                                   -2.83                    1395.0
# 4                                   -0.35                    1406.0
# ...                                   ...                       ...
# 9559                                -2.57                    2088.0
# 9560                                -0.08                    1608.0
# 9561                                -0.11                    2218.0
# 9562                                -4.68                     557.0
# 9563                                -0.12                    1266.0
#
#       InsolationFlux[Earthflux  InsolationFluxUpperUnc.[Earthflux  \
# 0                        93.59                              29.45
# 1                         9.11                               2.87
# 2                        39.30                              31.04
# 3                       891.96                             668.95
# 4                       926.16                             874.33
# ...                        ...                                ...
# 9559                   4500.53                            3406.38
# 9560                   1585.81                            1537.86
# 9561                   5713.41                            5675.74
# 9562                     22.68                               2.07
# 9563                    607.42                             600.39
#
#       InsolationFluxLowerUnc.[Earthflux  TransitSignal-to-Nois  \
# 0                                -16.65                   35.8
# 1                                 -1.62                   25.8
# 2                                -10.49                   76.3
# 3                               -230.35                  505.6
# 4                               -314.24                   40.9
# ...                                 ...                    ...
# 9559                           -1175.26                  453.3
# 9560                            -502.22                   10.6
# 9561                           -1836.94                   12.3
# 9562                             -10.95                   14.0
# 9563                            -194.33                    8.2
#
#       TCEPlanetNumbe  StellarEffectiveTemperature[K  \
# 0                1.0                         5455.0
# 1                2.0                         5455.0
# 2                1.0                         5853.0
# 3                1.0                         5805.0
# 4                1.0                         6031.0
# ...              ...                            ...
# 9559             1.0                         5638.0
# 9560             1.0                         6119.0
# 9561             1.0                         6173.0
# 9562             1.0                         4989.0
# 9563             1.0                         6469.0
#
#       StellarEffectiveTemperatureUpperUnc.[K  \
# 0                                       81.0
# 1                                       81.0
# 2                                      158.0
# 3                                      157.0
# 4                                      169.0
# ...                                      ...
# 9559                                   139.0
# 9560                                   165.0
# 9561                                   193.0
# 9562                                    39.0
# 9563                                   158.0
#
#       StellarEffectiveTemperatureLowerUnc.[K  \
# 0                                      -81.0
# 1                                      -81.0
# 2                                     -176.0
# 3                                     -174.0
# 4                                     -211.0
# ...                                      ...
# 9559                                  -166.0
# 9560                                  -220.0
# 9561                                  -236.0
# 9562                                  -128.0
# 9563                                  -225.0
#
#       StellarSurfaceGravity[log10(cm/s**2)  \
# 0                                    4.467
# 1                                    4.467
# 2                                    4.544
# 3                                    4.564
# 4                                    4.438
# ...                                    ...
# 9559                                 4.529
# 9560                                 4.444
# 9561                                 4.447
# 9562                                 2.992
# 9563                                 4.385
#
#       StellarSurfaceGravityUpperUnc.[log10(cm/s**2)  \
# 0                                             0.064
# 1                                             0.064
# 2                                             0.044
# 3                                             0.053
# 4                                             0.070
# ...                                             ...
# 9559                                          0.035
# 9560                                          0.056
# 9561                                          0.056
# 9562                                          0.030
# 9563                                          0.054
#
#       StellarSurfaceGravityLowerUnc.[log10(cm/s**2)  StellarRadius[Solarradii  \
# 0                                            -0.096                     0.927
# 1                                            -0.096                     0.927
# 2                                            -0.176                     0.868
# 3                                            -0.168                     0.791
# 4                                            -0.210                     1.046
# ...                                             ...                       ...
# 9559                                         -0.196                     0.903
# 9560                                         -0.224                     1.031
# 9561                                         -0.224                     1.041
# 9562                                         -0.027                     7.824
# 9563                                         -0.216                     1.193
#
#       StellarRadiusUpperUnc.[Solarradii  StellarRadiusLowerUnc.[Solarradii  \
# 0                                 0.105                             -0.061
# 1                                 0.105                             -0.061
# 2                                 0.233                             -0.078
# 3                                 0.201                             -0.067
# 4                                 0.334                             -0.133
# ...                                 ...                                ...
# 9559                              0.237                             -0.079
# 9560                              0.341                             -0.114
# 9561                              0.341                             -0.114
# 9562                              0.223                             -1.896
# 9563                              0.410                             -0.137
#
#       RA[decimaldegrees  Dec[decimaldegrees  Kepler-band[mag]  \
# 0             291.93423           48.141651            15.347
# 1             291.93423           48.141651            15.347
# 2             297.00482           48.134129            15.436
# 3             285.53461           48.285210            15.597
# 4             288.75488           48.226200            15.509
# ...                 ...                 ...               ...
# 9559          297.18875           47.093819            14.082
# 9560          286.50937           47.163219            14.757
# 9561          294.16489           47.176281            15.385
# 9562          296.76288           47.145142            10.998
# 9563          297.00977           47.121021            14.826
#
#       ExoplanetCandidate  ExoplanetConfirmed
# 0                    1.0                 2.0
# 1                    1.0                 2.0
# 2                    1.0                 1.0
# 3                    0.0                 0.0
# 4                    1.0                 2.0
# ...                  ...                 ...
# 9559                 0.0                 0.0
# 9560                 1.0                 1.0
# 9561                 0.0                 0.0
# 9562                 1.0                 1.0
# 9563                 0.0                 0.0
#
# [7803 rows x 39 columns]

# %%
df_candidate_0 = df[df['ExoplanetCandidate'] == 0]
df_candidate_1 = df[df['ExoplanetCandidate'] == 1]

x_0 =  df_candidate_0.drop(columns=['ExoplanetCandidate','ExoplanetConfirmed'])
x_1 = df_candidate_1.drop(columns=['ExoplanetCandidate','ExoplanetConfirmed'])

y_0 = df_candidate_0.ExoplanetCandidate
y_1 = df_candidate_1.ExoplanetCandidate

print("Cadidate==0 has")
print(x_0.shape, y_0.shape)
print("Cadidate==1 has")
print(x_1.shape, y_1.shape)

# Split 50% of the data for training set and 50% for testing set

x_train_0, x_test_0, y_train_0, y_test_0 = train_test_split(x_0, y_0, test_size=0.5, random_state=2021)
x_train_1, x_test_1, y_train_1, y_test_1 = train_test_split(x_1, y_1, test_size=0.5, random_state=2021)

print("Shape of x_train_0:", x_train_0.shape)
print("Shape of x_test_0:", x_test_0.shape)
print("Shape of y_train_0:", y_train_0.shape)
print("Shape of y_test_0:", y_test_0.shape)

print("Shape of x_train_1:", x_train_1.shape)
print("Shape of x_test_1:", x_test_1.shape)
print("Shape of y_train_1:", y_train_1.shape)
print("Shape of y_test_1:", y_test_1.shape)
# Out:
# Cadidate==0 has
# (3741, 37) (3741,)
# Cadidate==1 has
# (4062, 37) (4062,)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 17
#      13 print(x_1.shape, y_1.shape)
#      15 # Split 50% of the data for training set and 50% for testing set
# ---> 17 x_train_0, x_test_0, y_train_0, y_test_0 = train_test_split(x_0, y_0, test_size=0.5, random_state=2021)
#      18 x_train_1, x_test_1, y_train_1, y_test_1 = train_test_split(x_1, y_1, test_size=0.5, random_state=2021)
#      20 print("Shape of x_train_0:", x_train_0.shape)
#
# NameError: name 'train_test_split' is not defined

# %%
num_sample = 10  # Sample per class, total = 2000

# Take the first 1000 samples (500 from each class) from the training set for X_train and Y_train
X_train = np.concatenate((x_train_0.iloc[:num_sample, :].values, x_train_1.iloc[:num_sample, :].values), axis=0)
Y_train = np.concatenate((y_train_0.iloc[:num_sample].values, y_train_1.iloc[:num_sample].values), axis=0)

# Take the first 1000 samples (500 from each class) from the testing set for X_test and Y_test
X_test = np.concatenate((x_test_0.iloc[:num_sample, :].values, x_test_1.iloc[:num_sample, :].values), axis=0)
Y_test = np.concatenate((y_test_0.iloc[:num_sample].values, y_test_1.iloc[:num_sample].values), axis=0)

# Sanity Check
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)

np.savetxt('./middle_data/X_train.txt', X_train)
np.savetxt('./middle_data/X_test.txt', X_test)
np.savetxt('./middle_data/Y_train.txt', Y_train)
np.savetxt('./middle_data/Y_test.txt', Y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 num_sample = 10  # Sample per class, total = 2000
#       3 # Take the first 1000 samples (500 from each class) from the training set for X_train and Y_train
# ----> 4 X_train = np.concatenate((x_train_0.iloc[:num_sample, :].values, x_train_1.iloc[:num_sample, :].values), axis=0)
#       5 Y_train = np.concatenate((y_train_0.iloc[:num_sample].values, y_train_1.iloc[:num_sample].values), axis=0)
#       7 # Take the first 1000 samples (500 from each class) from the testing set for X_test and Y_test
#
# NameError: name 'x_train_0' is not defined

# %% [markdown]
# ### Preprocess Finished

# %%
# Load the saved NumPy arrays from .txt files
X_train = np.loadtxt("./middle_data/X_train.txt")
X_test = np.loadtxt("./middle_data/X_test.txt")
Y_train = np.loadtxt("./middle_data/Y_train.txt")
Y_test = np.loadtxt("./middle_data/Y_test.txt")

# Optional: Print shapes to verify successful loading
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("Y_train shape:", Y_train.shape)
print("Y_test shape:", Y_test.shape)

# The index of the best features in the header_list
important_features_id = np.array([
                         3,
                         4,
                         5,
                         8])

# Take only the best features

X_train = X_train[:, important_features_id[:3]]
X_test = X_test[:, important_features_id[:3]]

n_qubits = len(X_train[0])
# Out:
# X_train shape: (2000, 37)
# X_test shape: (2000, 37)
# Y_train shape: (2000,)
# Y_test shape: (2000,)

# %%
dev_kernel = qml.device("braket.aws.qubit", device_arn="arn:aws:braket:::device/quantum-simulator/amazon/dm1", wires=n_qubits)
#dev_kernel = qml.device("default.qubit", wires=n_qubits)

projector = np.zeros((2**n_qubits, 2**n_qubits))
projector[0, 0] = 1

@qml.qnode(dev_kernel)
def kernel(x1, x2):
    """The quantum kernel."""
    AngleEmbedding(x1, wires=range(n_qubits))
    qml.adjoint(AngleEmbedding)(x2, wires=range(n_qubits))
    return qml.expval(qml.Hermitian(projector, wires=range(n_qubits)))

def kernel_matrix(A, B):
    """Compute the matrix whose entries are the kernel
       evaluated on pairwise data from sets A and B."""
    return np.array([[kernel(a, b) for b in B] for a in A])

# %%
svm = SVC(kernel=kernel_matrix,max_iter=10)
svm.fit(X_train, Y_train)
